# %%
import camb
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
f = np.loadtxt('./COM_PowerSpect_CMB-TT-full_R3.01.txt')
multipole=f[:,0]
Sky_Variance=f[:,1]
low=f[:,2]
high=f[:,3]
plt.plot(multipole, Sky_Variance, '.')

# %%
def get_spectrum(pars,lmax=3000):
    #print('pars are ',pars)
    H0=pars[0]
    ombh2=pars[1]
    omch2=pars[2]
    tau=pars[3]
    As=pars[4]
    ns=pars[5]
    pars=camb.CAMBparams()
    pars.set_cosmology(H0=H0,ombh2=ombh2,omch2=omch2,mnu=0.06,omk=0,tau=tau)
    pars.InitPower.set_params(As=As,ns=ns,r=0)
    pars.set_for_lmax(lmax,lens_potential_accuracy=0)
    results=camb.get_results(pars)
    powers=results.get_cmb_power_spectra(pars,CMB_unit='muK')
    cmb=powers['total']
    tt=cmb[:,0]    #you could return the full power spectrum here if you wanted to do say EE
    return tt[2:]

plt.ion()

pars=np.asarray([60,0.02,0.1,0.05,2.00e-9,1.0])
#pars2 = np.asarray([69, 0.022, 0.12, 0.06, 2.1e-9, 0.95])

#pars = pars2

print(len(get_spectrum(pars)))

planck=np.loadtxt('COM_PowerSpect_CMB-TT-full_R3.01.txt',skiprows=1)
ell=planck[:,0]
spec=planck[:,1]
errs=0.5*(planck[:,2]+planck[:,3]);
model=get_spectrum(pars)
model=model[:len(spec)]
resid=spec-model
chisq=np.sum( (resid/errs)**2)
print("chisq is ",chisq," for ",len(resid)-len(pars)," degrees of freedom.")
#read in a binned version of the Planck PS for plotting purposes
planck_binned=np.loadtxt('COM_PowerSpect_CMB-TT-binned_R3.01.txt',skiprows=1)
errs_binned=0.5*(planck_binned[:,2]+planck_binned[:,3]);
plt.clf()
plt.plot(ell,model)
plt.errorbar(planck_binned[:,0],planck_binned[:,1],errs_binned,fmt='.')
plt.show()
# Out:
# 3049
# chisq is  15267.937968222595  for  2501  degrees of freedom.

# %%
get_spectrum(pars)
# Out:
# array([795.08939514, 764.03290509, 731.80917071, ...,  27.49815315,
#         27.4542531 ,  27.41065202])

# %%
def ndiff(fun, args, pos):
    #recalculate dx so that it represents the smallest amount between x and the next representable number 
    #in double-point precision.
    #Calculate two points used in numerical derivative.
    x = args[pos]
    dx = 1e-5 * x
    args[pos] = x+dx
    fx1 = fun(args)
    args[pos] = x-dx
    fx2 = fun(args)
    deriv = (fx1 - fx2)/(2*dx)
    #We use the roundoff error as it gives an upper bound. We know that an estimate for 
    #the roundoff error is epsilon*f(x)/delta, as shown in class.
    return deriv

def Model_function(args):
    y = get_spectrum(args)
    derivs = np.zeros([len(y), len(args)])
    for i in range(len(args)):
        derivs[:, i] = ndiff(get_spectrum, args, i)
    return y, derivs

def fit_newton(fun, args, y, niter=10):
    for i in range(niter):
        model, deriv = get_all_deriv(fun, args)
        r = y-model
        lhs = deriv.T@deriv
        rhs = derivs.T@r
        dm = np.linalg(lhs)@rhs
        args = args+dm
        chisq = np.sum(r**2)
        print('On iteration', i, 'chisq is ', chisq, 'with step ', dm)
        return args
    
        

'''def d3(func,args,pos):
    x=args[pos]
    dx = x*1e-3
    args1 = np.copy(args)
    args2 = np.copy(args)
    args3 = np.copy(args)
    args4 = np.copy(args)
    args1[pos] = x-2*dx
    args2[pos] = x-dx
    args3[pos] = x+dx
    args4[pos] = x+2*dx
    print(func(args1), func(args2))
    return (-0.5*func(args1) + func(args2) - func(args3) + 0.5*func(args4))/(dx**3)

def ideal_dx(func,args,pos,dx0):
    third_deriv = d3(func, args, pos)
    x = args[pos]
    # Handling of numpy arrays since funky math here is the only thing
    # that isn't directly automatically extended by numpy
    if isinstance(x,np.ndarray):
        # Supress those pesky divide by zero errors since we handle those cases.
        with np.errstate(divide = 'ignore'):
            dx1 = np.cbrt(3*func(args)*1e-16/(d3(func,args,pos)))
        dx1[np.where(np.isnan(dx1))] = dx0
        dx1[np.where(np.isinf(dx1))] = dx0
        return np.abs(dx1)
    else:
        if third_deriv.all() == 0.0:
            return dx0
        dx1 = np.cbrt(3*func(args)*1e-16/(d3(func,args,pos)))
        return np.abs(dx1)'''
# Out:
# "def d3(func,args,pos):\n    x=args[pos]\n    dx = x*1e-3\n    args1 = np.copy(args)\n    args2 = np.copy(args)\n    args3 = np.copy(args)\n    args4 = np.copy(args)\n    args1[pos] = x-2*dx\n    args2[pos] = x-dx\n    args3[pos] = x+dx\n    args4[pos] = x+2*dx\n    print(func(args1), func(args2))\n    return (-0.5*func(args1) + func(args2) - func(args3) + 0.5*func(args4))/(dx**3)\n\ndef ideal_dx(func,args,pos,dx0):\n    third_deriv = d3(func, args, pos)\n    x = args[pos]\n    # Handling of numpy arrays since funky math here is the only thing\n    # that isn't directly automatically extended by numpy\n    if isinstance(x,np.ndarray):\n        # Supress those pesky divide by zero errors since we handle those cases.\n        with np.errstate(divide = 'ignore'):\n            dx1 = np.cbrt(3*func(args)*1e-16/(d3(func,args,pos)))\n        dx1[np.where(np.isnan(dx1))] = dx0\n        dx1[np.where(np.isinf(dx1))] = dx0\n        return np.abs(dx1)\n    else:\n        if third_deriv.all() == 
# ...

# %%
Model_function([60,0.02,0.1,0.05,2.00e-9,1.0])

# %%
def ndiff(fun, args, pos, dx):
    #recalculate dx so that it represents the smallest amount between x and the next representable number 
    #in double-point precision.
    #Calculate two points used in numerical derivative.
    x = args[pos]
    args[pos] = x+dx
    fx1 = fun(args)
    print(fx1)
    args[pos] = x-dx
    fx2 = fun(args)
    print(fx2)
    deriv = (fx1 - fx2)/(2*dx)
    #We use the roundoff error as it gives an upper bound. We know that an estimate for 
    #the roundoff error is epsilon*f(x)/delta, as shown in class.
    return deriv
def get_all_deriv(fun, args, dx):

def fit_newton(fun, args, niter=10):
    for i in range(niter):
        deriv = ndiff(fun, args, pos, ) 
        
ndiff(get_spectrum, [60,0.02, 0.1, 0.05, 2e-9, 1], 4, 1e-10)
# Out:
# [834.84400128 802.23482283 768.40008277 ...  29.02456037  28.97758544
#   28.93091765]
# [755.33480199 725.8310133  695.21830185 ...  25.98520854  25.94432959
#   25.90374121]
# array([3.97545996e+11, 3.82019048e+11, 3.65908905e+11, ...,
#        1.51967592e+10, 1.51662793e+10, 1.51358822e+10])

# %%
get_spectrum([58, 0.02, 0.1, 0.05, 2e-09, 1])
# Out:
# array([768.88296629, 743.79454311, 715.91195781, ...,  28.4460358 ,
#         28.39417736,  28.34279059])

# %%
agrs=[1, 2, 3]
agrs[0]=x+dx
print(agrs)
# Out:
# [3, 2, 3]
